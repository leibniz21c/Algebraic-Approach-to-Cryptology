# %% [markdown]
# # CH02. 다표식 치환 암호
# ---
# <strong>2.1. 동음이의 암호</strong><br>
# 챕터1에서 한 암호방식은 단표식 치환 암호들이고, 이는 동일한 치환 규칙이 유지가된다.<br>
# 반면에 다표식 암호는 한 번에 한 문자를 치환하지만 문자마다 다른 치환 규칙을 사용한다.<br>
# 예를들어 한 문자를 여러 문자로 암호화하는 암호를 가리켜 Homophonic cipher(동음이의 암호)라 한다. 일반적으로 동음이의어라는 말은 서로 철자가 다른 두 단어가 발음이 같은 관계를 의미한다. 암호학에서 동음이의어란 암호문에서는 다른 형태를 갖지만 동일한 문자로 복호화되는 문자를 의미한다. 굉장히 간단하게도 이 방법을 사용하면 문자 빈도 분석에 대하여 일차적으로 안전하다. <br><br>
#
# >케르크호프스 원리 : Key를 제외한 모든 정보가 알려지더라도 암호체계는 안전해야한다.
#
# 만약, 케르크호프스 원리를 기본 가정으로 삼는다면, 암호의 원리를 추정하기 위해 암호체계를 훔칠 필요가 없을 때도 있다. 만약 암호문을 해독하는 입장에서 동음이의 암호가 사용된다는 것을 어떻게 추정할 수 있을까? 일반적으로 동음이의 암호체계에는 문자가 26개 이상이다. 그러나 모든 암호문 문자가 실제로 메시지에 쓰이지 않을 수도 있고 여러가지 다른 변수가 많다. 실제 예시에서 추정을 해보자.<br><br>
#
# 첫 번째 단계는 암호문 문자 각각에 대한 출현 빈도를 표로 만들었을때 다음과 같은 상황이 발생했다고 생각하자.<br>
# > 암호문에 나타난 문자는 모두 23개이다.
#
# 이는 다루고 있는 언어의 전체 문자 수가 26개 이하이거나, 모든 문자를 다 사용하지 않아도 되는 다중문자 치환 방식을 사용했거나, 아니면 평문에서 일부 문자가 나타나지 않았다는 의미이다.<br><br>
#
# 두 번째 단계는 조사한 암호문의 관찰 빈도와 영어 텍스트의 기대 빈도를 비교하는 것이다. 다음과 같은 상황이 발생했다고 생각하자.<br>
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">e</th>
#     <th class="tg-0pky">12.7%</th>
#     <th class="tg-0lax">X</th>
#     <th class="tg-0lax">14.6%</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">t</td>
#     <td class="tg-0lax">9.1%</td>
#     <td class="tg-0lax">L</td>
#     <td class="tg-0lax">9.3%</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">a</td>
#     <td class="tg-0lax">8.2%</td>
#     <td class="tg-0lax">Q</td>
#     <td class="tg-0lax">9.3%</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">o</td>
#     <td class="tg-0lax">7.5%</td>
#     <td class="tg-0lax">G</td>
#     <td class="tg-0lax">7.1%</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">...</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">...</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">k</td>
#     <td class="tg-0lax">.8%</td>
#     <td class="tg-0lax">W</td>
#     <td class="tg-0lax">.6%</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">j</td>
#     <td class="tg-0lax">.2%</td>
#     <td class="tg-0lax">M</td>
#     <td class="tg-0lax">.3%</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">x</td>
#     <td class="tg-0lax">.2%</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">q</td>
#     <td class="tg-0lax">.1%</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">z</td>
#     <td class="tg-0lax">.1%</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# 표를 보면 주어진 암호문은 기대 빈도가 가장 낮은 문자들이 우연히 사용되지 않은 단순 치환 암호라고 추정할 수 충분히 있다. 만약 동음이의 암호가 사용되었다면 기대 빈도가 낮은 문자는 더 많이 나타나고 기대 빈도가 높은 문자는 오히려 더 적게 나타났을 것이다. 즉, 알파벳 발생 빈도의 분포형태가 일반적인 문자 빈도 분포와 많이 달라질 것이다. 이런 관찰 결과를 보다 수학적으로 분석하기 위한 도구가 Indexx of Coincidence(동시발생지수)이다. <br><br>
#
# <strong>2.2. 문자 빈도와 동시발생지수</strong><br>
# 동시발생지수를 공부하기전에 확률이라는 토픽을 조금만 살펴보자. 확률이란 어떤 사건이 일어나는 경우의 수가 K가지 일 때, 어떤 사건이 일어나는 확률이
# $ \frac {K}{N}$인 것을 뜻한다. 그래서 확률 $p$는 다음과 같은 범위를 가진다. $ 0 \le p \le 1 $ <br><br>
#
# 먼저 각 문자가 동일한 빈도로 출현한다는 가정에서 무작위로 분포되어 있다고 가정할때, 첫 번째 뽑은 문자가 a일 확률은 $\frac{1}{26}$이다. 두 번째 선택에서 a를 뽑을 확률이 $\frac{1}{26}$이므로, 첫 번째에서 뽑은 문자와 두 번째에서 뽑은 문자가 연속으로 a일 확률은 $\frac{1}{26} \times \frac{1}{26}$이다. 각 문자별로 동시에 발생했다고 가정할때 확률의 합은 다음과 같다.
# $$ \frac{1}{26^2} + \frac{1}{26^2} + \cdots \frac{1}{26^2} = \sum_{k=1}^{26} \frac{1}{26^2} = \frac{1}{26} \approx .038 $$
# 이처럼 선택된 텍스트에서 문자를 하나씩 두 번 뽑을 때, 서로 같은 문자를 뽑을 확률을 동시발생지수라 한다. 무작위의 영어 텍스트(일반적으로 문자 빈도 분석에서 사용하는 것과 다른 분포)에서 동시발생지수는 대략 0.038, 즉 3.8%이다.<br><br>
#
# 실제 영어 텍스트(문자 빈도 분석에 사용하는 분포)에서 문자를 뽑는다고 가정하자. 일단 a가 뽑힐 확률은 8.2%, 소수로 나타내면 0.082이다. 이때 a를 연속으러 뽑을 확률은 $(0.082)^2$ 이다. 모든 문자에 대해서 합을 구하면 다음과 같다.
# $$ (.082)^2 + (.015)^2 + (.028)^2 + \cdots + (.001)^2 \approx .066 $$
# 즉, 실제 영어 텍스트의 동시발생지수는 대략 0.066, 즉 6.6%이다.<br><br>
#
# 무작위 영어 알파벳의 분포는 0.038에 가까운 값이 나올 것이고, 의미가 있는 텍스트에서는 당연히 0.066에 가까운 값이 나올 것이다.<br><br>
#
# 첫 번째로 텍스트에 단순 치환 암호를 적용하더라도 동시발생지수는 변하지 않는다. 더하는 순서는 바뀌더라도 총합은 같기 때문이다. 그러므로 단순 치환 암호를 사용한 암호문의 동시발생지수는 대략 0.066이다. 하지만 동음이의 암호를 사용해 암호문을 만들었다면 동시발생지수는 분명히 달라진다. 동음이의 방식에서는 문자 간의 출현 빈도 차가 적어지기 때문에 동시발생지수는 동시발생지수는 0.038과 0.066 사이가 된다. <br><br>
#
# 위의 예시에서 다루던 예시를 계산하면 0.068이 나오는데 단순 치환 암호를 사용했다는 쪽으로 무게가 실린다. 수업에서 이 예시에 대해서 조금더 다루겠다.<br><br>
#
# 동음이의암호는 여기까지 하자. 이제 르네상스 시대로 넘어올때이다.

# %% [markdown]
# <strong>2.3. 알베르티 암호</strong><br>
# 1466년 혹은 1467년 초에 'De Componendis Cifris(암호에 대한 논고)'라는 25쪽짜리 논문이 유럽에 발표된다. 이 논문은 유럽의 초기 암호기술과 암호해독에 대한 학술저작물로서, 유럽 최초로 문자 빈도 분석법을 사용하는 방법과 무효 문자, 동음이의암호의 개념에 대해 설명한다. 게다가 최초의 치환 암호기계이면서 최초의 진정한 다표식 암호방식(암호문이 진행중에 치환 방식이 바뀐다는 순수성에 근거, 동음이의암호는 치환 방식이 바뀌는 것에 의의를 두기 힘들다.)이라 할 수 있는 암호 원판에 대한 소개가 실려있다. 이 논문의 저자는 '레온 바티스타 알베르티'라는 사람인데, 이는 이탈리아의 저술가이자 미술가이며 건축가, 운동선수, 철학지인 르네상스 시대의 팔방미인이라고 소개되는 것 같다. 일단 암호 원판을 보자.<br>
# ![알베르티 암호 원판](https://ncache.ilbe.com/files/attach/new/20130505/377678/109073993/1178808113/f5078ed8e7c50a23239607c80a19e346.jpg)<br>
# <strong>Figure2.3.1</strong><br>
# 위의 그림을 보면 일단은 평문(소문자), 암호문(대문자)에 대해서 순서가 있게 둘다 배치가 되어있음을 알 수 있다. 알베르티 암호 원판은 바깥 쪽의 큰 판, 안 쪽의 작은 판으로 이루어져 있으며, 이 것들은 분리가 되어있고 중심에 핀을 꽂아 회전할 수 있게 되어 있다. 위의 사진은 알파벳이 순서에 맞게 배치되어 있으며, 이를 돌려서 간단하게 덧셈암호에 대해서 단표식 단일 치환을 할 수 있음을 알 수 있다. 하지만, 강의화면에서 볼 수 있는 원판에서는 암호문부분의 알파벳 순서는 무질서하게 분산시켜져 있음을 알 수 있다. 이때 작은 원판을 한 자리에 고정하고 문자를 대응시키면 고전적이지만 일반적인(무질서한) 단표식 단일 치환 암호가 된다.<br><br>
#
# 실습을 감상하기전에 2가지 정의를 하자. 첫 번째는 암호문의 문자 중에서 하나의 문자를 선택해 '지표문자'라고 부르자. 원판을 돌릴때 기준이 되는 문자라고 생각해주면 편할 것 같다. 두 번째는 평문 문자중에서 하나의 문자를 선택해 '키 문자'라고 부르자. 그리고 이를 암호문의 시작 부분에 적기로 약속하자. 즉, 키 문자가 지표 문자와 동일한 위치에 오도록 원판을 회전하여 암호표처럼 활용할 수 있다. 첫 번째 실습을 보자.<br><br>
#
# 실습에서도 알 수 있듯이, 이는 <strong>단표식</strong> 단일치환 암호방식이다. 즉, 문자 빈도 분석법에 굉장히 취약한 암호방식이다. 하지만, 알베르티는 여기서 좋은 아이디어를 제시하여 문자 빈도 분석법에 대비할 수 있는 최초(엄밀하게는 아니지만)의 다표식 치환 암호방식을 고안해낸다. 과정은 간단하다. 단어 3~4개를 암호화하고 나면, 원판을 새로 돌려 암호 규칙을 바꿔주고, 암호문에 새로운 키 문자를 삽입해 암호 변경을 표시하는 방법이다. 두 번째 실습을 보자.<br><br>
#
# 생각보다 쉬운 방식으로 다표식 암호화 방식을 구현할 수 있음을 알았다. 그럼 이 알베르티 암호의 복호화는 어떻게 진행될까? 우선 복호화를 하는 입장과 부호화를 하는 입장 모두 같은 암호 원판을 가지고 있어야 한다. 같은 암호 원판이라는 말은, 애초에 안쪽판이 무질서하게 분산되어져 있는데, 이러한 단일 치환 규칙의 순서는 맞아야 한다는 뜻이다. 추가적으로 부호, 복호화하는 사람은 지표 문자를 서로 공유하고 있어야한다. 만약, 이 두 조건이 충족되면, 암호문에 키 문자가 나올 때마다 지표 문자와 동일한 위치에 오도록 원판을 돌리고, 알파벳끼리 대응시켜 복호화를 진행하면된다. 이 까지 읽어보면 이번 주 실습은 어렵지 않을까라는 생각이 들 수 있는데, 생각보다 쉬우니 걱정말고 진행하자. 복호화 실습을 보자.<br><br>
#
# 제일 재미있는 부분이다. 알베르티 암호를 부호화, 복호화에 대해서 공부를 했는데, 이제 남은 것은 어떻게 공격할까에 대한 문제이다. 잘 생각해보자. 만약 암호체계가 알베르티 암호라는 사실을 알고, 암호문에 등장하는 소문자가 키 문자라는 사실을 알더라도 원판을 모른다면 복호화할 수 없다. 만약 키 문자를 충분히 자주 바꾸고, 메시지가 그다지 길지 않아 키문자가 중복 사용되지 않는다면, 빈도 분석 공격을 사용하기도 힘들다. 키문자가 중복 사용이 된다면, 메시지 길이가 (충분할지는 모르겠지만)길어지기에, 특정 키문자가 사용된 파트만 분할하여 빈도 분석 공격을 진행하는 것은 가능은 하다. 그래서 메시지의 길이가 충분히 길어서 원판의 위치를 중복해서 사용하는 경우가 많아지면(빈도 분석 공격을 하기에 충분히) 빈도 분석 공격을 통해 알베르티 암호를 해독할 가능성은 충분히 있다. 추가적으로 중복해서 사용하는 키 문자가 많아진다면 암호판 자체를 만들어버리는 것도 충분히 가능하다. 실습을 보고 지나가자.

# %% [markdown]
# <strong>2.4. 정사각형 암호표 : 트리테미우스 암호표</strong><br>
# 알베르티가 유럽 최초로 암호에 관한 책을 썼고 최초로 건축에 관한 인쇄물을 펴낸 인물로 인정을 받지만, 최초로 인쇄된 암호 책을 저술한 사람은 요하네스 트리테미우스(Johannes Trithemius)이다. 이 사람의 행적을 보면 조금 재미있는데, 최근 발견된 증거가 더 웃기다. 어쨋든, 트리테미우스는 암호학자들 사이에서 '정사각형 암호' 또는 '트리테미우스 암호'로 불리는 암호로 가장 잘 알려있다고 한다.<br><br>
#
# 우선 트리테미우스 암호의 기본 암호표를 보자. 알베르티 암호 원판의 암호문 알파벳이 평문 알파벳과 같은 순서로 배열되어 있다고 생각하면 쉽다.
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Plain Text : </th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">a</th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">b</th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">c</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">d</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">e</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">v</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">w</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">x</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">y</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">z</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text : </td><td style="background-color:#ffffff;border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text :</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">G</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text :</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">G</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">H</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text :</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">T</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">U</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text :</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">U</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Cipher Text :</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td></tr></tbody></table>
# <strong>Figure2.4.1</strong>

# %% [markdown]
# 한 칸, 두 칸, 세 칸 등 처음 상태로 되돌아올 때까지 계속 회전하면서 위의 암호표가 완성된다. 만약 평문 "abc"를 암호문으로 바꾸면 "BDF"가 된다. 암호 원판과 유사한 정보를 가지고 있으나, 우선적으로 모든 정보를 한꺼번에 보여주고 있음을 알 수 있다. 부호화를 진행하는 사람이 원할때마다 키 문자를 쓰고 원판의 위치를 바꾸는 형태가 아니라, 정사각형 암호표를 따라 차례대로 내려가면서 문자 하나마다 암호문 문자로 하나씩 치환하는 것이다. 암효표의 맨 마지막 줄에 이르면 처음부터 다시 시작한다. <br><br>
#
#  이러한 형태를 Progressive System(점진적 치환 시스템)이라고 하고, 이러한 시스템에서는 연속해서 나타는 두 글자의 흔적이 나타나지 않는 것이 특징이다. 위의 표는 트리테미우스 암호의 기본 형태이고, 눈치챘겠지만, 곱셈암호의 형태가 암호표상에 나타난다. 실제로 트리테미우스는 알파벳 역순으로 문자를 배열한 암호표뿐만 아니라 다양한 순서로 암호표를 구성했다고 한다. 그러면 이러한 암호표에서는 암호키를 어떻게 추가할 수 있을까?<br><br>
#
# 지오반 바티스타 벨라조(Giovan Battista Bellaso)라는 사람이 이탈리아에 있었다. 1553년에 그가 출판한 암호학에 대한 소책자에서 정사각형 암호에 키를 추가하는 아이디어를 처음 제안하였다. 벨라조는 정사각형 암호표의 왼쪽에 키를 추가하는 방안을 생각하였다. 암호표를 확인하자.
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 333px" class="tg"><colgroup><col style="width: 58px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"><col style="width: 25px"></colgroup><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal"></th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">a</th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">b</th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#3166ff;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">c</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">d</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">e</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">v</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">w</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">x</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">y</th><th style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">z</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="background-color:#ffffff;border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">G</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">G</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">H</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">T</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">U</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">D</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">U</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">A</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">B</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">C</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">E</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">F</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">...</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">V</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">W</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">X</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Y</td><td style="border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Z</td></tr></tbody></table>
# <strong>Figure2.4.2</strong>

# %% [markdown]
# 부호화를 하는 사람과 복호화를 하는 사람이 단어나 구로 된 키를 미리 약속을 한다 이를 Keyword(키워드)라고 하자. 그리고 키워드를 필요한 만큼 반복해서 평문의 위 칸에 적는다. 이후 평문의 각 문자에 대해 해당 키와 대응되는 알파벳 행에서 암호문 문자를 찾는다. 실습을 보며 확인하자.<br><br>
#
# 힐 암호의 경우(단표식 다중 문자 치환)는 평문에서는 같은 문자이더라도 위치에 따라 암호문에서는 다른 문자로 나타날 수 있는데, 어떤 경우에는 3개의 s가 각각 M, E, X로 치환된다. 이런 형태의 다표식 암호를 Repeating-Key Cipher(반복키 암호)라고 부른다. 반복키 암호의 키는 반드시 그런 것은 아니지만 단어나 어구가 가장 흔하게 사용된다. 이렇게 벨라조는 순서가 다양한 키 알파벳과 암호문 알파벳을 사용해 더 복잡한 암호체계를 만들었다. <br><br>
#
# 그런데 대수적 관점에서 보면 트리테미우스 암호표를 사용하는 것이 모듈러 연산에 있어서 표현이 간결하다는 장점이 있다. 식은 다음과 같다.
# $$ C_i \equiv P_i + k_{i \,\bmod \,\ length \,\ of \,\ keyword} \,\bmod \,\ 26 $$
# 식에 대한 설명은 수업시간에 진행하겠다. 언듯보면 덧셈암호와 비슷한 이러한 방식은 현대 디지털 스트림 암호의 초기 형태이다.
#  위의 식을 통해서 간단하게 부호화할 수 있다. 추가적으로 복호화도 식을 조금만 변형하면 쉽게 가능하다. <br><br>

# %% [markdown]
# <strong>2.5. 동시발생지수를 이용한 다표식 치환 암호의 접근</strong><br>
# 이때까지 언급된 다표식 암호들의 키를 생각해보자. 알베르티 암호의 경우는 키 문자가 중간중간에 암호문에서 등장하면서 지표문자를 고정하며 해결했다. 트리테미우스 암호표의 경우는 순서가 존재하며 치환 방식을 변경하며 치환하였다. 벨라조의 방식은 Keyword(키워드)가 등장하며 반복적으로 치환의 방식이 변경되었다. 즉, 반복키를 사용하였다. 키의 길이가 한정되기 때문에 일정 길이의 문자열에 대해 사용하고 나면 결국 키를 반복해서 사용해야 한다. 키에 사용된 문자의 개수를 암호의 Period(주기)라 하는데,
# $$ C_i \equiv P_i + k_{i \,\bmod \,\ length \,\ of \,\ keyword} \,\bmod \,\ 26 $$
# 위의 식에서 length of keyword에 해당하는 부분이다. 지금부터는 반복키 암호를 해독하는 방법을 탐구해볼 것인데, 그 전에 잘 생각해보아야 할 문제가 있다. '사용된 암호가 반복키 암호인지 판별하는 문제'가 당연하게 앞서야한다. 이때 우리는 동음이의 암호에 썻던 도구를 그대로 이용할 수 있다. 바로 '동시발생지수'이다.<br><br>
#
# 예시와 함께 알아보자. 기본 정사각형 암호에서 키워드를 'LEON'이라고 두고, 평문 "thecatonthematbattedagnat"를 치환한다고 생각하자. 그러면 다음과 같이 치환된다. "FMTQMYDBFMTAMYQOFYTRMLCOF" 이 중에서 키 'L'에 의해서 치환된 친구들은 몇 번째  친구들일까? $ 1 + 4k, \,\ k \in \mathbb{N} $번째 친구들인 것을 알 수 있다. 키 'E'는 $ 2 + 4k $, 키 'O'는 $ 3 + 4k $, 키 'N'은 $ 4k $번째이다. 한 가지만 확인해보자. 키 'L'에 의해서 치환된 암호문의 문자들은 다음과 같다.<br><br>
#
# F, M, F, M, F, M, F<br><br>
#
# 위의 친구들에 한해서는 단표식 단일 치환이라고 말할 수 있다. 덕분에 우리는 여기서 동시발생지수를 따져 볼 수 있다. 이 친구들에 한해서는 문자를 두 개 뽑는다면 두 문자는 같은 암호방식에 의해 암호화되기 때문에 두 문자가 같은 문자일 확률은 대략 0.066이 나와야한다. 반면에, 서로 다른 키를 사용해서 치환된 친구들에 대해서는 두 문자가 같은 문자일 확률이 0.038에 가까워 질 것이다. <br><br>
#
# 전체적으로 따져보자. 지금부터는 정사각형 암호체계 자체에서의 동시발생지수를 논리적으로 근사해보자. 전체 문자의 수를 $n$이라고 하고, 키워드의 길이(주기)를 $l$이라고 하자. 전체에서 첫 번째 문자를 뽑는 경우의 수는 $n$이다. 두 번째 문자를 첫 번째와 같은 키를 사용하여 치환된 문자들의 집합에서 뽑는다면 가능한 경우의 수는 $(\frac{n}{l} -1) $이고, 이때 뽑은 문자가 같은 문자일 확률은 $.066$ 이다. 두 번째 문자를 첫 번째와 다른 열에서 뽑는다면 가능한 경우의 수는 $ (n - \frac{n}{l}) $이고, 이때 뽑은 문자가 같은 문자일 확률은 $.038$ 이다. 문자 2개를 뽑을 때 가능한 모든 경우의 수는 $ n \times (n - 1) $이므로, 두 문자가 같은 문자일 확률, 즉 정사각형 암호체계에서 동시발생지수는 다음과 같은 식으로 나타낼 수 있다. (사실 이에 대해서는 여러가지 확률이론이 단적으로 반영되어있습니다. 확률론에서의 Axiom.Additive, Theorem.Total Probability Theorem를 참고하셔도 됩니다.)
# $$ \frac{n \times (n/l - 1) \times .066 + (n - n/l) \times .038}{n \times (n-1)} = \frac{n/l - 1}{n-1} \times .066 + \frac{n - n/l}{n - 1} \times .038 $$
# 이 식에 있어서 여러가지 상황을 생각해보자. 일단 $ l = 1 $인 경우이다. 이건 그냥 단표식 단일 치환암호와 똑같다. 실제로 위의 식에 대입하면 값이 $.066$이 나오는 것을 확인할 수 있다. $ l = n $인 경우는 어떤 경우인가? 이 때는 모든 평문 문자는 각각 무작위로 선택된 서로 다른 문자로 치환된다. 암호문은 사실상 규칙이 없어 완전히 무작위적이며 동시발생지수는 $.038$에 수렴한다. <br><br>
#
# 만약, 암호문의 길이가 충분히 길다면, 위의 식에 조건을 한가지 추가할 수 있다.
# $$ \lim_{n \rightarrow \infty} \frac{n \times (n/l - 1) \times .066 + (n - n/l) \times .038}{n \times (n-1)} = \frac{1}{l} \times .066 + \frac{l-1}{l} \times .038 $$
# 이 식을 이용하여, 키워드의 길이에 대해서 몇가지 계산을 해보자. <br>
# 주기가 1인 경우는 값이 $.066$이 나온다. 주기가 2인 경우는 값이 $.052$, 주기가 3인 경우부터는 $.047$, $.045 \,\ \cdots$ 오 같이 나오고, 이 값들을 이용해서 어떤 암호문을 보고 주기(키워드의 길이) 값을 유추할 수 있다. <br><br>
#
# 근데 잘 생각해봐야 하는 것이, 일단 가정이 암호문이 굉장히 많이 길어야하고, 만약 그렇다 하더라도, 근사하는 값에 대해서 쉽게 유추를 할 수 없는 경우가 있다. 예를 들어서 어떤 암호문의 동시발생지수가 $.046$으로 나왔을 때, 이 친구의 주기를 3으로 보아야하나? 아니면 4로 보아야하나? 와 이거 큰일났다.

# %% [markdown]
# <strong>2.6. Kasiski Test</strong><br>
# 위와 같은 상황에서 주기를 찾아내는 방법은 19세기 중반에 두 사람에 의해서 각자 독립적으로 동시에 발견되었다. 그중에 한 사람은 찰스 배비지(Charles Babbage)이다. 그는 과학, 수학, 공학 등 많은 분야의 연구를 했고, 오늘날 다른 무엇보다 프로그래밍이 가능한 컴퓨터를 처음 고안한 과학자로 많이 알려져 있다. 하지만 주기를 찾아내는 방법에 대해서 연구 결과를 출판하지 못했고, 실제로 이에 대해서 출판한 사람은 프리드리히 카지스키(Friedrich Kasiske)이다. 암호학에 많은 기여를 하지는 않았지만, 프로이센군의 소령이었던 카지스키는 군 복무 동안에는 암호와 관련해 별다른 활동을 하지 않았다. 퇴역한 후에 그는 다표식 치환 암호를 주제로 얇은 책을 펴냈다. <br><br>
#
# 카지스키 테스트의 기본원리는 평문에서 반복되는 부분이 반복되는 키를 기준으로 같은 위치에 오면 암호문도 반복된다는 사실에 근거한다. 예를 들어서 위의 예시에서 'at'이 평문에서 네 번 반복되는데 처음 두 'at'은 키워드의 같은 위치에 오지만, 세 번째와 네 번째 'at'은 처음 두 경우와 같은 위치에 오지 않는다. 그러므로 처음 두 'at'은 모두 'MY'로 암호화되었지만 나머지 두 'at'은 다르게 'OF'로 암호화되었다. <br><br>
#
# 카지스키 테스트는 암호문에서 반복되는 문자열을 찾는 것에서 출발한다. 위의 에시에서는 FMT, MY, OF가 있다. 정말 간단한데, 반복 문자열의 각각 첫 문자부터 다음 반복이 나타나기 직전까지 문자의 개수를 센다. 위 3가지의 반복되는 문자열에 대해서 모두 간격이 8이다. 즉, 주기가 8의 약수라는 결론을 도출할 수 있다. <br><br>
#
# 물론, 암호문이 충분히 길때 사용할 수 있는 방법이다. 암호문이 길어지면 카지스키 테스트가 복잡해지지만 더 효과적이다. 수업에서 예시를 확인하며 진행하자.<br><br>
#
# 아 물론 카지스키 테스트에서 유추한 경우는 정말 순전히 우연에 의해 나타났을 수도 있다. 그래서 동시발생지수와 함께 사용한다. 동시발생지수를 풀어서 만약
# $$ l \approx 4.6 $$
# 이라는 결과가 나왔고, 암호 주기가 5를 약수로 가질 확률이 높다는 카지스키 테스트의 결과로 부터 주기가 5임이 거의 확실해진다.

# %% [markdown]
# <strong>2.7. Kappa Test</strong><br>
# 사실 카지스키 테스트도 잘 생각해보면, 주기에 맞게 반복이 일어났기 때문에 사용할 수 있는 방법이다. 그래서 한 가지 방법을 더 알아볼 것이다. 카파 테스트는 동시발생지수를 이용한다., 반복키가 사용되었는지 여부와 상관없이 두 암호문이 동일한 다표식 치환 암호를 사용해서 암호화되었는지를 판정해 준다. 어떤 두 평문이 존재할 때, 임의로 위치를 하나 선택했을 때 그 위치에 오는 두 평문의 문자가 서로 같은 문자일 확률은 얼마일까? 즉, 두 문자 모두 a가 될 확률, 둘 다 b가 될 확률 등등을 모두 더한 값은 얼마일까? 간단하다. $.066$에 근사한다. 당연한 결과이다. 위의 상황은 어떤 일반적인 영어 평문에서의 문자의 동시발생지수와 동일하다. 당연히 어떤 일반적이지 않은 무작위로 알파벳을 배치할 경우는 동시발생지수 기댓값이 $.038$에 근사한다. 이제 이 어떤 일반적인 두 영어 평문을 트리테미우스 정사각형 암호방식으로 암호화한다고 가정하자. 이때 암호문에도 일치하는 문자가 그대로 생기고, 두 암호문이 같은 키를 사용해 암호화된 것이라면 동시발생지수의 기댓값은 여전히 $.066$이다. 반면에 서로 다른 키를 사용해 암호화한다면 일치하는 문자는 순전히 우연한 결과인 것에 자명하다. 실제로 계산해보면 $.038$에 근사한다. <br><br>
#
# 이것을 키워드의 길이를 결정하는 데 어떻게 이용할 수 있을까? 암호문 한 개를 보고있는데, 당연히 다른 비교를 하는 암호문이 등장할 것 이다. 그 새로운 암호문은 간단하게 기존의 암호문을 변위(Displacement)하여 만들 수 있다. 이게 무슨 말인지 <strong>2.5</strong> 에서 다룬 상황을 보자.<br>
# 암호문은 다음과 같았다. "FMTQMYDBFMTAMYQOFYTRMLCOFYWSO"<br>
# 변위라는 말은 앞에서부터 텍스트를 밀어내어서 새로운 문자열을 만든다라는 의미이다. 만약 1번의 변위를 하면, 암호문은 다음과 같다.<br>
# "0FMTQMYDBFMTAMYQOFYTRMLCOFYWSO" 언제 가장 의미가 있을까? 바로 주기만큼 변위했을 때이다. 실제 예시에서 주기가 4였으니까, 4만큼 변위를 하면 암호문은 다음과 같다. <br>
# "0000FMTQMYDBFMTAMYQOFYTRMLCOFYWSO" 이 결과와 기존의 암호문에 대한 동시발생지수는 이전에 본 결과와 똑같이 $.066
# $에 근사할 것이다. 다음의 표는 카지스키 테스트에 의해서 주기가 5를 약수로 가질 확률이 높은 암호문의 카파 테스트 결과이다.<br>
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 245px" class="tg"><colgroup><col style="width: 54px"><col style="width: 97px"><col style="width: 94px"></colgroup><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">변위량</th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">동시발생 횟수 </th><th style="border-color:#000000;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">동시발생지수</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">1</td><td style="background-color:#ffffff;border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">7</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.030</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">2</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">10</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.043</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">3</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">9</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.038</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">4</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">11</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.047</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">5</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">14</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.060</td></tr><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">6</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">15</td><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.064</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">7</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">15</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.064</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">8</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">9</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.038</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">9</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">11</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.047</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">10</td><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">14</td><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.060</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">11</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">10</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.043</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">12</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">3</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.013</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">13</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">14</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.060</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">14</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">12</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.051</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">15</td><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">17</td><td style="border-color:black;border-style:solid;border-width:1px;color:#fe0000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">.072</td></tr></tbody></table>
# <strong>Figure.2.7.1</strong>

# %% [markdown]
# 물론 6, 7도 주기의 후보가 될 수 있지 않을까? 라고 생각할 수 있지만, 그러면 당연하게도 12(6 X 2), 14(7 X 2)의 경우, 즉, 주기의 배수의 동시발생지수도 0.066에 수렴해야 논리적으로 말이 된다. 5의 경우는 10, 15에 대해서 동시발생지수가 충분히 높음이 보장이 되어있기 때문에, 카파테스트의 결과에 근거하여 주기는 5일 가능성이 매우 높다라고 판단할 수 있다. <br>
# 그럼 정리해서, 어떤 반복키가 사용된 암호문에서의 동시발생지수 공식과, 카지스키 테스트, 카파 테스트 3가지를 결합하면 주기가 5일 확률은 굉장히 높다라고 판단할 수 있다. 암호문에서 주기를 알고있다면, 당연히 주기마다 한번씩 같은 방식으로 치환된 암호가 돌아온다. 이 경우에 한해서는 단표식 단일치환 암호방식이므로, 무차별 대입 공격을 하든, 문자 빈도 분석 공격을 하든 뚫을 방법이 굉장히 많아진다. 이때 만약에 키가 다섯 문자씩 반복된다는 것을 알때 암호문을 다섯 열로 정렬할 수 있다. 그러면 같은 열에 대해서는 같은 규칙의 치환이 사용되었기 때문에 훨씬 보기 쉬워지는데, 이를 중첩 배열(Superimposition)이라고 한다.

# %% [markdown]
# <strong>2.8. 다표식 치환 암호의 곱암호</strong><br>
# 반복키를 사용하는 다표식 치환 암호에서 제 2의 키를 사용해 암호화를 중복하면 안정성을 향상할 수 있을까에 대해서 생각해보자. 아마 단표식 단일 치환암호를 탐구할 때, 헛수고였다는 사실을 기억할 것이다. 만약에 키워드 GLASS를 사용해 메시지를 암호화한 결과와 키워드 QUEEN을 사용해서 암호화한 결과를 더하여 암호문을 얻는다고 생각해보자. (주기가 서로 같은 키워드를 사용) 결과를 보면 흥미롭다.
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 300px" class="tg"><colgroup><col style="width: 81px"><col style="width: 44px"><col style="width: 38px"><col style="width: 40px"><col style="width: 48px"><col style="width: 49px"></colgroup><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">키워드 1:</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">G</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">L</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">A</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">S</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">S</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">숫자:</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">7</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">12</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">19</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">19</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">키워드 2:</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Q</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">U</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">E</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">E</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">N</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">숫자:</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">17</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">21</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">5</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">5</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">14</td></tr></tbody></table>
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 307px" class="tg"><colgroup><col style="width: 88px"><col style="width: 44px"><col style="width: 38px"><col style="width: 40px"><col style="width: 48px"><col style="width: 49px"></colgroup><thead><tr><th style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">합(mod 26):</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">24</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">7</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">6</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">24</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">7</th></tr></thead><tbody><tr><td style="border-color:inherit;border-style:solid;border-width:1px;color:#000000;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">최종 키워드:</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">X</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">G</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">F</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">X</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">G</td></tr></tbody></table><br>
# <strongFigure.2.8.1</strong>

# %% [markdown]
# 결국 "XGFXG"라는 키워드로 암호화하는 것과 같은 결과를 보여주고, 암호화를 하는 과정만 번거러워질 뿐이다. 그러면 주기가 서로 다른 키워드를 사용하면 어떻게 될까? 예를 들어서 "RABBIT"으로 암호화하고 나서 다시 "CURIOUSER"로 암호화 한다면, 눈치챘겠지만, 결국 주기가 6과 9의 최소공배수인 18인 암호문이 될 뿐이다. 즉, 아무 의미가 없다. 똑같은 반복키를 사용하는 암호문일 뿐이다. 상식적으로 생각하면 조금 안정성이 좋긴한데, 그럴거면 차라리 주기가 2인 키워드와 9인 키워드를 사용하는게 더 합리적인 것은 자명하다.
